# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_blobs
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# ## Q6.A

# %%
centers=[[-1,-1], [1,1]]

# %%
A,B=make_blobs(n_samples=250, centers=centers, cluster_std=1/8, random_state=42)

# %%
plt.scatter(A[:,0], A[:,1],  cmap="bwr", alpha=0.3)

plt.show()

# %% [markdown]
# ## Q6.B

# %%
np.random.seed(42)

# %%
A=np.random.randn(250,2)*(1/8)+[-1,-1]

# %%
B=np.random.randn(250,2)*(1/8)+[1,1]

# %%
plt.scatter(A[:,0], A[:,1], c="b",alpha=0.3)
plt.scatter(B[:,0], B[:,1], c="r",alpha=0.3)
plt.show()

# %% [markdown]
# ## Q6.C

# %%
centers=[[-1,-1], [1,1]]

# %%
A,B=make_blobs(n_samples=250, centers=centers, cluster_std=4, random_state=42)

# %%
plt.scatter(A[:,0], A[:,1], c=B, cmap="bwr", alpha=0.3)

plt.show()

# %% [markdown]
# ## Q6.D

# %%
from sklearn.datasets import make_circles

# %%
B,_=make_circles(n_samples=500,random_state=42, factor=0.999999)

# %%
B.shape
# Out:
# (500, 2)

# %%
A,_=make_blobs(n_samples=250, centers=[[0,0]], cluster_std=1/8, random_state=42)

# %%
plt.scatter(A[:,0], A[:,1], c="b", alpha=0.3)
plt.scatter(B[:,0], B[:,1], c="r", alpha=0.3)
plt.show()

# %%
type(A)
# Out:
# numpy.ndarray

# %%
type(B)
# Out:
# numpy.ndarray
